# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series(np.random.randn(12), index=[el for el in range(1, 13)])
s
# Out:
# 1     0.963392
# 2     0.360223
# 3    -1.318249
# 4    -0.432448
# 5     1.841693
# 6    -1.638868
# 7    -0.155210
# 8     0.758998
# 9    -0.923135
# 10   -0.755852
# 11    1.054195
# 12   -0.007044
# dtype: float64

# %%
s[s > s.median()]
# Out:
# 1     0.963392
# 2     0.360223
# 5     1.841693
# 8     0.758998
# 11    1.054195
# 12   -0.007044
# dtype: float64

# %%
s.array
# Out:
# <PandasArray>
# [    0.963391993351811,     0.360222632395029,   -1.3182493196889016,
#    -0.4324482177080475,    1.8416928098145422,   -1.6388680587960411,
#   -0.15520959005257423,    0.7589977166017935,    -0.923134863807981,
#    -0.7558516624545739,     1.054194541711642, -0.007044366889914172]
# Length: 12, dtype: float64

# %%
s.to_numpy()
# Out:
# array([ 0.96339199,  0.36022263, -1.31824932, -0.43244822,  1.84169281,
#        -1.63886806, -0.15520959,  0.75899772, -0.92313486, -0.75585166,
#         1.05419454, -0.00704437])

# %%
np.exp(s)
# Out:
# 1     2.620570
# 2     1.433649
# 3     0.267603
# 4     0.648918
# 5     6.307206
# 6     0.194200
# 7     0.856236
# 8     2.136134
# 9     0.397272
# 10    0.469610
# 11    2.869663
# 12    0.992980
# dtype: float64

# %%
s * 2 + 5
# Out:
# 1     6.926784
# 2     5.720445
# 3     2.363501
# 4     4.135104
# 5     8.683386
# 6     1.722264
# 7     4.689581
# 8     6.517995
# 9     3.153730
# 10    3.488297
# 11    7.108389
# 12    4.985911
# dtype: float64

# %%
s2 = s[1:] + s[:-1]
s2
# Out:
# 1          NaN
# 2     0.720445
# 3    -2.636499
# 4    -0.864896
# 5     3.683386
# 6    -3.277736
# 7    -0.310419
# 8     1.517995
# 9    -1.846270
# 10   -1.511703
# 11    2.108389
# 12         NaN
# dtype: float64

# %%
s2 ** 2 + 5
# Out:
# 1           NaN
# 2      5.519041
# 3     11.951125
# 4      5.748046
# 5     18.567330
# 6     15.743554
# 7      5.096360
# 8      7.304310
# 9      8.408712
# 10     7.285247
# 11     9.445305
# 12          NaN
# dtype: float64

# %%
s2 = s2.fillna(0)
s2
# Out:
# 1     0.000000
# 2     0.720445
# 3    -2.636499
# 4    -0.864896
# 5     3.683386
# 6    -3.277736
# 7    -0.310419
# 8     1.517995
# 9    -1.846270
# 10   -1.511703
# 11    2.108389
# 12    0.000000
# dtype: float64

# %%
s + s2
# Out:
# 1     0.963392
# 2     1.080668
# 3    -3.954748
# 4    -1.297345
# 5     5.525078
# 6    -4.916604
# 7    -0.465629
# 8     2.276993
# 9    -2.769405
# 10   -2.267555
# 11    3.162584
# 12   -0.007044
# dtype: float64

# %%
# %matplotlib notebook

# %%
plt.plot(s)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.pie(s ** 2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x7fcafcf83be0>,
# ...
#  [Text(1.0687096443628417, 0.2604989367460998, ''),
#   Text(0.9591564273939986, 0.5385340730063244, ''),
#   Text(0.6010826405351095, 0.9212489670264714, ''),
#   Text(0.09039673965561117, 1.0962793573992151, ''),
#   Text(-0.8188526740612525, 0.734493225416502, ''),
#   Text(-0.7387011191717721, -0.8150586828777249, ''),
#   Text(-0.042001437058440526, -1.0991978344615796, ''),
#   Text(0.12776547932027507, -1.0925547960143969, ''),
#   Text(0.5121845160786718, -0.9734819060923818, ''),
#   Text(0.8271589573899005, -0.7251262367406471, ''),
#   Text(1.0552225210726525, -0.3106532327549091, ''),
#   Text(1.099999999912073, -1.390825176307163e-05, '')])

# %%
df = pd.DataFrame(np.random.rand(4,8), columns=list('ABCDEFGH'))
df
# Out:
#           A         B         C         D         E         F         G  \
# 0  0.648098  0.461179  0.992271  0.501581  0.108866  0.701736  0.159011
# 1  0.804994  0.260057  0.980768  0.559150  0.972067  0.406479  0.022439
# 2  0.790672  0.683863  0.984947  0.439727  0.233718  0.188846  0.938451
# 3  0.419583  0.974650  0.545190  0.947500  0.839703  0.027105  0.617616
#
#           H
# 0  0.357538
# 1  0.690250
# 2  0.268524
# 3  0.379314

# %%
df5 = pd.DataFrame({
    'col one': ['1.1', '2.2', '3.3'],
    'col two': ['4.4', '5.5', '6.6'],
    'col three': ['7.7', '8.8', '-']
})
df5
# Out:
#   col one col two col three
# 0     1.1     4.4       7.7
# 1     2.2     5.5       8.8
# 2     3.3     6.6         -

# %%
# replace column spaces:
df5.columns = df5.columns.str.replace(' ', '_')
df5
# Out:
#   col_one col_two col_three
# 0     1.1     4.4       7.7
# 1     2.2     5.5       8.8
# 2     3.3     6.6         -

# %%
df5.dtypes
# Out:
# col_one      object
# col_two      object
# col_three    object
# dtype: object

# %%
# convert strings to numbers
df5 = df5.apply(pd.to_numeric, errors='coerce').fillna(0)
df5
# Out:
#    col_one  col_two  col_three
# 0      1.1      4.4        7.7
# 1      2.2      5.5        8.8
# 2      3.3      6.6        0.0

# %%
df5.dtypes
# Out:
# col_one      float64
# col_two      float64
# col_three    float64
# dtype: object
